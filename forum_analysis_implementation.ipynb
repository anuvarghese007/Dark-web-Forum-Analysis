# %%
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:root@localhost:3306/dnf_2018')

# %%
df=pd.read_sql_table("wallstreet",engine)
df
# Out:
#        postID  threadID                                        threadTitle  \
# 0           6         5                                                 Hi
# 1           7         5                                                 Hi
# 2           8         6              WSM Updates - Changelog (Page 1 of 4)
# 3          11         5                                                 Hi
# 4          13         6              WSM Updates - Changelog (Page 1 of 4)
# ...       ...       ...                                                ...
# 45367   71451     20321                                     Opening Leases
# 45368   71454     20321                                     Opening Leases
# 45369   71455     19423  Utility bills, bank statements and European PP...
# 45370   71457     20187                          Need legit USA CVV seller
# 45371   71458     20321                                     Opening Leases
#
# ...

# %%
import nltk
import re
nltk.download('wordnet')
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\anuva\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\anuva\AppData\Roaming\nltk_data...
# True

# %%
def preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    '''
    Preprocess a string.
    :parameters:
         text: string - name of column containing text
         lst_stopwords: list - list of stopwords to remove
         flg_stemm: bool - whether stemming is to be applied
         flg_lemm: bool - whether lemmitisation is to be applied
    returns cleaned text
    '''

    ## clean (convert to lowercase and remove punctuations and characters and then strip)
    text = re.sub(r'[^\w\s]', '', str(text).lower().strip())
            
    ## Tokenize (convert from string to list)
    lst_text = text.split()
    
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_text = [ps.stem(word) for word in lst_text]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_text = [lem.lemmatize(word) for word in lst_text]
            
    ## back to string from list
    text = " ".join(lst_text)
    return text

# %%
lst_stopwords = nltk.corpus.stopwords.words("english")

# %%
df["clean_text"] = df["flatContent"].apply(lambda x: preprocess_text(x, flg_stemm=False, flg_lemm=True, lst_stopwords=lst_stopwords))
df.head()
# Out:
#    postID  threadID                            threadTitle  \
# 0       6         5                                     Hi
# 1       7         5                                     Hi
# 2       8         6  WSM Updates - Changelog (Page 1 of 4)
# 3      11         5                                     Hi
# 4      13         6  WSM Updates - Changelog (Page 1 of 4)
#
#                                                 URL       subforum authorName  \
# 0  http://x7bwsmcore5fmx56.onion/viewtopic.php?id=5  Introductions   Punka421
# 1  http://x7bwsmcore5fmx56.onion/viewtopic.php?id=5  Introductions        WSM
# 2  http://x7bwsmcore5fmx56.onion/viewtopic.php?id=6  Announcements        WSM
# 3  http://x7bwsmcore5fmx56.onion/viewtopic.php?id=5  Introductions    Estrazy
# 4  http://x7bwsmcore5fmx56.onion/viewtopic.php?id=6  Announcements        WSM
#
#   postAuthorMembership postAuthorJoinDate  authorReputation  \
# 0           New member         2016-10-26                -3
# ...

# %%
df1 = df[['subforum','flatContent','clean_text']]
df1.sample(5)
# Out:
#                  subforum                                        flatContent  \
# 40694  Bitcoin & Multisig  \nPlease contact support and provide all these...
# 43183        Psychedelics  \n^ wat da fraq! ^Penis Envy #6 We have a lot ...
# 28123       Digital goods  \nrandom147 wrote:24kings wrote:what the diffe...
# 869     General Questions  \nRegardless, weapons attract a lot of unwante...
# 26726  Software & Malware  \nOur listing is up:http://wallst4qihu6lvsa.on...
#
#                                               clean_text
# 40694  please contact support provide information als...
# 43183  wat da fraq penis envy 6 lot beautiful penis e...
# 28123  random147 wrote24kings wrotewhat difference rd...
# 869    regardless weapon attract lot unwanted attenti...
# 26726  listing uphttpwallst4qihu6lvsaonionoffer23973 ...

# %%
train_set = df1.loc[0:35000]
valid_set = df1.loc[35000:40000]

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

def vader_sentiment_result(sent):
    scores = analyzer.polarity_scores(sent)
    
    if scores["neg"] > scores["pos"]:
        return 0

    return 1

train_set["label"] = train_set["clean_text"].apply(lambda x: vader_sentiment_result(x))
valid_set["label"] = valid_set["clean_text"].apply(lambda x: vader_sentiment_result(x))
# Out:
# C:\Users\anuva\AppData\Local\Temp/ipykernel_26960/2927035011.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set["label"] = train_set["clean_text"].apply(lambda x: vader_sentiment_result(x))
# C:\Users\anuva\AppData\Local\Temp/ipykernel_26960/2927035011.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_set["label"] = valid_set["clean_text"].apply(lambda x: vader_sentiment_result(x))

# %%
train_set.sample(100)
# Out:
#                  subforum                                        flatContent  \
# 8527                Fraud  \nleseid wrote:I am looking for bank accounts ...
# 6047                Fraud  \nSHABS wrote:stevejobs12 wrote:Well @SHABS i ...
# 22169     Feature Request  \nthis is a really good idea buyers can build ...
# 23185       Announcements  \n-----BEGIN PGP SIGNED MESSAGE-----Hash: SHA2...
# 14207  Software & Malware  \nBump.\nMarket & Store @ WSM: http://wallstyi...
# ...                   ...                                                ...
# 34607          Stimulants  \nThat's a good idea. We will look into this. ...
# 6514                 MDMA  \nI received my sample today!!The package arri...
# 22609       Carding Stuff  \nBe careful listening to other people's advic...
# 28925       Carding Stuff  \nmetalernie wrote:Hello does anybody buy from...
# 25432               Fraud  \n@Overdead What country are you in? I've got ...
#
# ...

# %%
train_set.drop(['vader_result'],axis=1)
# Out:
#                                 subforum  \
# 0                          Introductions
# 1                          Introductions
# 2                          Announcements
# 3                          Introductions
# 4                          Announcements
# ...                                  ...
# 34996                               MDMA
# 34997  Wanted - Carding, Fraud & Related
# 34998                              Fraud
# 34999                         Stimulants
# 35000                           Services
#
#                                              flatContent  \
# 0      \nJust thought I'd introduce myself. I am new ...
# 1                \nHello  Nice to see you here!Regards\n
# 2      \nHello everyone.I would like to tell you that...
# 3      \nHello Punka! nice to meet you!As you asked h...
# 4      \nChangelog from Wednesday, 2nd November 2016F...
# ...                                                  ...
# 34996  \nHey man I wasnt trying to dispute the order ...
# ...
